# %%
# Import libraries
import numpy as np
import random
import matplotlib.pyplot as plt
from statistics import stdev
import scipy.stats as stats

# %% [markdown]
# Simulation

# %%
marbles <- [B, B, B, P, R]
