# %%
# Import libraries
import numpy as np
import random
import matplotlib.pyplot as plt
from statistics import stdev
import scipy.stats as stats

# %%
y = np.random.randint(low = 1, high = 10, size = 100) # Get numbers from 1 to 10-1=9

# %%
y
# Out:
# array([4, 1, 7, 7, 7, 5, 9, 4, 6, 5, 8, 8, 2, 3, 3, 3, 4, 3, 8, 6, 1, 4,
#        3, 3, 6, 4, 3, 9, 5, 5, 5, 9, 8, 5, 7, 4, 2, 7, 5, 9, 1, 7, 5, 8,
#        8, 4, 8, 3, 4, 4, 2, 6, 7, 1, 3, 2, 8, 6, 5, 7, 8, 2, 8, 1, 5, 9,
#        7, 3, 4, 3, 1, 8, 3, 9, 5, 4, 6, 8, 1, 4, 8, 2, 6, 4, 9, 1, 4, 2,
#        7, 7, 8, 1, 9, 8, 6, 4, 9, 4, 8, 6])

# %%
# Make a boxplot
plt.boxplot(y)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1cf253abd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1cf2357f10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1cf23b62d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1cf23b6510>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1cf235b310>,
#   <matplotlib.lines.Line2D at 0x7f1cf235b210>]}

# %%
# Generate another random dataset
x = np.random.randint(low = 1, high = 1000, size = 100) # Get numbers from 1 to 10-1=9

# Make a boxplot
plt.boxplot(x)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1cf1ddc4d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1cf1dc20d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1cf1deab90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1cf1deab10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1cf1de9f50>,
#   <matplotlib.lines.Line2D at 0x7f1cf1de9390>]}

# %%
# Generate another random dataset
z = np.random.randint(low = 1, high = 10, size = 100) # Get numbers from 1 to 10-1=9
print(min(z))
print(max(z))
z = np.append(z, 14)

# Make a boxplot with outlier
plt.boxplot(z)
# Out:
# 1
# 9
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1cf199db10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1cf19a2b90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1cf19a8bd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1cf19a8690>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1cf19a2110>,
#   <matplotlib.lines.Line2D at 0x7f1cf19a2650>]}

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Cows', 'Pigs', 'Chickens', 'Dogs', 'Cats'
sizes = [10, 15, 30, 5, 5]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', # autopct = auto-percent (calculates percentages for you)
        shadow=True, startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
